# %%
Answers for Week 1

* Name: Bas Baas
* Username: bbaas
* Student s-number: s6441068
* Group (AS1, etc.): AS6

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![obama.jpg](attachment:4fe93ac7-ec83-4380-a7fa-94e1cb606075.jpg)

# %%
y = 1

y *= 6
y *= 5
y *= 4
y *= 3
y *= 2

print (y)
# Out:
# 720

# %%
import math
from scipy.constants import c
from scipy.constants import h

Hz = 2.42e28

w = c / Hz
E = h * c / w

print (E)
# Out:
# 1.6035089763e-05

# %%
from scipy.constants import G

m1 = 7.342e22
m2 = 5.9722e24
r = 385000600

F = G * ((m1 * m2)/r**2)

print (F)
# Out:
# 1.974384051807571e+20

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %% [markdown]
# Q1.10

# %% [markdown]
# ![ss%20filezilla%20prognum.png](attachment:ss%20filezilla%20prognum.png)

# %% [markdown]
# Q1.15
#
# a
# pws means the path to your current directory
# b
# . means the current directory
# .. means the parent directory

# %% [markdown]
# Q1.16
# cd /desktop

# %% [markdown]
# 1.11

# %% [markdown]
# ![tree%20prognum.png](attachment:tree%20prognum.png)

# %% [markdown]
# 1.12
